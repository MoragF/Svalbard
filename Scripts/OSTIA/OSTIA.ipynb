# %%
import numpy as np
import datetime as dt

import xarray as xr

# %%
URL = 'https://upwell.pfeg.noaa.gov/erddap/griddap/nasa_jpl_2fa2_cbe7_cd13.htmlTable?analysed_sst[(2010-01-01T12:00:00Z):1:(2021-03-24T12:00:00Z)][(55.025):1:(89.975)][(-179.975):1:(179.975)],analysis_error[(2010-01-01T12:00:00Z):1:(2021-03-24T12:00:00Z)][(55.025):1:(89.975)][(-179.975):1:(179.975)],sea_ice_fraction[(2010-01-01T12:00:00Z):1:(2021-03-24T12:00:00Z)][(55.025):1:(89.975)][(-179.975):1:(179.975)],mask[(2010-01-01T12:00:00Z):1:(2021-03-24T12:00:00Z)][(55.025):1:(89.975)][(-179.975):1:(179.975)]'
nc = xr.open_dataset(URL)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3.6/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     197             try:
# --> 198                 file = self._cache[self._key]
#     199             except KeyError:
#
# /usr/lib/python3.6/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# ...

# %%
index = (date >= dt.datetime(2000, 1, 1)) & (date < dt.datetime(2004, 1, 1))
sub_select = temp_stack[index, :, :]
